# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns   
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0              1.1            No                   85.0          8.0
# 1              2.3            No                   97.3          4.6
# 2              1.3            No                   94.8          8.0
# 3              1.0            No                   71.0          9.2
# 4              0.5            No                   90.9          4.9
# ..             ...           ...                    ...          ...
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 0           Fair                   6                   Master
# 1           Good                   6              High School
# 2           Poor                   1              High School
# 3           Poor                   4                   Master
# 4           Fair                   3                   Master
# ..           ...                 ...                      ...
# 995         Fair                   2              High School
# 996         Poor                   1              High School
# 997         Good                   5                 Bachelor
# 998         Fair                   0                 Bachelor
# 999         Good                   2                 Bachelor
#
#     internet_quality  mental_health_rating extracurricular_participation  \
# 0            Average                     8                           Yes
# 1            Average                     8                            No
# 2               Poor                     1                            No
# 3               Good                     1                           Yes
# 4               Good                     1                            No
# ..               ...                   ...                           ...
# 995             Good                     6                           Yes
# 996          Average                     6                           Yes
# 997             Good                     9                           Yes
# 998          Average                     1                            No
# 999          Average                     8                            No
#
#      exam_score
# 0          56.2
# 1         100.0
# 2          34.3
# 3          26.8
# 4          66.4
# ..          ...
# 995        76.1
# 996        65.9
# 997        64.4
# 998        69.7
# 999        74.9
#
# [1000 rows x 16 columns]

# %%
#data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
#  12  internet_quality               1000 non-null   object
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   object
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), object(7)
# memory usage: 125.1+ KB

# %%
df.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# min                56.000000     3.200000            0.000000
# 25%                78.000000     5.600000            1.000000
# 50%                84.400000     6.500000            3.000000
# 75%                91.025000     7.300000            5.000000
# max               100.000000    10.000000            6.000000
#
#        mental_health_rating   exam_score
# count           1000.000000  1000.000000
# mean               5.438000    69.601500
# std                2.847501    16.888564
# min                1.000000    18.400000
# 25%                3.000000    58.475000
# 50%                5.000000    70.500000
# 75%                8.000000    81.325000
# max               10.000000   100.000000

# %%
#checking missing values
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
df.describe(include='object')
# Out:
#        student_id gender part_time_job diet_quality parental_education_level  \
# count         909    909           909          909                      909
# unique        909      3             2            3                        3
# top         S1000   Male            No         Fair              High School
# freq            1    440           713          396                      392
#
#        internet_quality extracurricular_participation
# count               909                           909
# unique                3                             2
# top                Good                            No
# freq                410                           620

# %%
df.describe(include='object').columns
# Out:
# Index(['student_id', 'gender', 'part_time_job', 'diet_quality',
#        'parental_education_level', 'internet_quality',
#        'extracurricular_participation'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0              1.1            No                   85.0          8.0
# 1              2.3            No                   97.3          4.6
# 2              1.3            No                   94.8          8.0
# 3              1.0            No                   71.0          9.2
# 4              0.5            No                   90.9          4.9
# ..             ...           ...                    ...          ...
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 0           Fair                   6                   Master
# 1           Good                   6              High School
# 2           Poor                   1              High School
# 3           Poor                   4                   Master
# 4           Fair                   3                   Master
# ..           ...                 ...                      ...
# 995         Fair                   2              High School
# 996         Poor                   1              High School
# 997         Good                   5                 Bachelor
# 998         Fair                   0                 Bachelor
# 999         Good                   2                 Bachelor
#
#     internet_quality  mental_health_rating extracurricular_participation  \
# 0            Average                     8                           Yes
# 1            Average                     8                            No
# 2               Poor                     1                            No
# 3               Good                     1                           Yes
# 4               Good                     1                            No
# ..               ...                   ...                           ...
# 995             Good                     6                           Yes
# 996          Average                     6                           Yes
# 997             Good                     9                           Yes
# 998          Average                     1                            No
# 999          Average                     8                            No
#
#      exam_score
# 0          56.2
# 1         100.0
# 2          34.3
# 3          26.8
# 4          66.4
# ..          ...
# 995        76.1
# 996        65.9
# 997        64.4
# 998        69.7
# 999        74.9
#
# [909 rows x 16 columns]

# %%
object_cols = df.select_dtypes(include="object").columns

for col in object_cols:
    df[col] = df[col].astype(str).str.strip().str.lower()

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        s1000   23  female                  0.0                 1.2
# 1        s1001   20  female                  6.9                 2.8
# 2        s1002   21    male                  1.4                 3.1
# 3        s1003   23  female                  1.0                 3.9
# 4        s1004   19  female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      s1995   21  female                  2.6                 0.5
# 996      s1996   17  female                  2.9                 1.0
# 997      s1997   20    male                  3.0                 2.6
# 998      s1998   24    male                  5.4                 4.1
# 999      s1999   19  female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0              1.1            no                   85.0          8.0
# 1              2.3            no                   97.3          4.6
# 2              1.3            no                   94.8          8.0
# 3              1.0            no                   71.0          9.2
# 4              0.5            no                   90.9          4.9
# ..             ...           ...                    ...          ...
# 995            1.6            no                   77.0          7.5
# 996            2.4           yes                   86.0          6.8
# 997            1.3            no                   61.9          6.5
# 998            1.1           yes                  100.0          7.6
# 999            1.9            no                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 0           fair                   6                   master
# 1           good                   6              high school
# 2           poor                   1              high school
# 3           poor                   4                   master
# 4           fair                   3                   master
# ..           ...                 ...                      ...
# 995         fair                   2              high school
# 996         poor                   1              high school
# 997         good                   5                 bachelor
# 998         fair                   0                 bachelor
# 999         good                   2                 bachelor
#
#     internet_quality  mental_health_rating extracurricular_participation  \
# 0            average                     8                           yes
# 1            average                     8                            no
# 2               poor                     1                            no
# 3               good                     1                           yes
# 4               good                     1                            no
# ..               ...                   ...                           ...
# 995             good                     6                           yes
# 996          average                     6                           yes
# 997             good                     9                           yes
# 998          average                     1                            no
# 999          average                     8                            no
#
#      exam_score
# 0          56.2
# 1         100.0
# 2          34.3
# 3          26.8
# 4          66.4
# ..          ...
# 995        76.1
# 996        65.9
# 997        64.4
# 998        69.7
# 999        74.9
#
# [909 rows x 16 columns]

# %%
df['gender'].value_counts()
# Out:
# gender
# male      440
# female    433
# other      36
# Name: count, dtype: int64

# %%
#Removing "Others" from gender

df = df[df["gender"] != "other"]

# %%
df["gender"].value_counts()
# Out:
# gender
# male      440
# female    433
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (873, 16)

# %%
df['age'].describe()
# Out:
# count    873.000000
# mean      20.465063
# std        2.304061
# min       17.000000
# 25%       18.000000
# 50%       20.000000
# 75%       22.000000
# max       24.000000
# Name: age, dtype: float64

# %%
df["parental_education_level"].value_counts()
# Out:
# parental_education_level
# high school    371
# bachelor       342
# master         160
# Name: count, dtype: int64

# %%
hour_cols = [
    "study_hours_per_day",
    "social_media_hours",
    "netflix_hours",
    "sleep_hours"
]

for col in hour_cols:
    df[col] = df[col].clip(lower=0, upper=24)

df[hour_cols].describe()
# Out:
# C:\Users\CSP\AppData\Local\Temp\ipykernel_884\4151872362.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower=0, upper=24)
# C:\Users\CSP\AppData\Local\Temp\ipykernel_884\4151872362.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower=0, upper=24)
# C:\Users\CSP\AppData\Local\Temp\ipykernel_884\4151872362.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower=0, upper=24)
# C:\Users\CSP\AppData\Local\Temp\ipykernel_884\4151872362.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].clip(lower=0, upper=24)
#        study_hours_per_day  social_media_hours  netflix_hours  sleep_hours
# count           873.000000          873.000000     873.000000   873.000000
# mean              3.531844            2.498855       1.820733     6.462314
# std               1.485679            1.162644       1.058287     1.229189
# min               0.000000            0.000000       0.000000     3.200000
# 25%               2.500000            1.700000       1.000000     5.600000
# 50%               3.500000            2.500000       1.800000     6.400000
# 75%               4.500000            3.300000       2.500000     7.300000
# max               8.300000            7.200000       5.400000    10.000000

# %%
df["attendance_percentage"].describe()
# Out:
# count    873.000000
# mean      83.879152
# std        9.432564
# min       56.000000
# 25%       77.500000
# 50%       84.300000
# 75%       90.700000
# max      100.000000
# Name: attendance_percentage, dtype: float64

# %%
df['exam_score'].describe()
# Out:
# count    873.000000
# mean      69.470332
# std       17.042099
# min       18.400000
# 25%       58.400000
# 50%       70.500000
# 75%       81.500000
# max      100.000000
# Name: exam_score, dtype: float64

# %%
df['mental_health_rating'].describe()
# Out:
# count    873.000000
# mean       5.466208
# std        2.861732
# min        1.000000
# 25%        3.000000
# 50%        5.000000
# 75%        8.000000
# max       10.000000
# Name: mental_health_rating, dtype: float64

# %%
df.isnull().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 873 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     873 non-null    object
#  1   age                            873 non-null    int64
#  2   gender                         873 non-null    object
#  3   study_hours_per_day            873 non-null    float64
#  4   social_media_hours             873 non-null    float64
#  5   netflix_hours                  873 non-null    float64
#  6   part_time_job                  873 non-null    object
#  7   attendance_percentage          873 non-null    float64
#  8   sleep_hours                    873 non-null    float64
#  9   diet_quality                   873 non-null    object
#  10  exercise_frequency             873 non-null    int64
#  11  parental_education_level       873 non-null    object
#  12  internet_quality               873 non-null    object
#  13  mental_health_rating           873 non-null    int64
#  14  extracurricular_participation  873 non-null    object
#  15  exam_score                     873 non-null    float64
# dtypes: float64(6), int64(3), object(7)
# memory usage: 115.9+ KB
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  873.000000           873.000000          873.000000     873.000000
# mean    20.465063             3.531844            2.498855       1.820733
# std      2.304061             1.485679            1.162644       1.058287
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.500000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             873.000000   873.000000          873.000000
# mean               83.879152     6.462314            3.051546
# std                 9.432564     1.229189            2.034305
# min                56.000000     3.200000            0.000000
# 25%                77.500000     5.600000            1.000000
# 50%                84.300000     6.400000            3.000000
# 75%                90.700000     7.300000            5.000000
# max               100.000000    10.000000            6.000000
#
#        mental_health_rating  exam_score
# count            873.000000  873.000000
# mean               5.466208   69.470332
# std                2.861732   17.042099
# min                1.000000   18.400000
# 25%                3.000000   58.400000
# 50%                5.000000   70.500000
# 75%                8.000000   81.500000
# max               10.000000  100.000000

# %%
df.drop(columns=["student_id"], inplace=True)
# Out:
# C:\Users\CSP\AppData\Local\Temp\ipykernel_884\1443768791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["student_id"], inplace=True)

# %%
df
# Out:
#      age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 0     23  female                  0.0                 1.2            1.1
# 1     20  female                  6.9                 2.8            2.3
# 2     21    male                  1.4                 3.1            1.3
# 3     23  female                  1.0                 3.9            1.0
# 4     19  female                  5.0                 4.4            0.5
# ..   ...     ...                  ...                 ...            ...
# 995   21  female                  2.6                 0.5            1.6
# 996   17  female                  2.9                 1.0            2.4
# 997   20    male                  3.0                 2.6            1.3
# 998   24    male                  5.4                 4.1            1.1
# 999   19  female                  4.3                 2.9            1.9
#
#     part_time_job  attendance_percentage  sleep_hours diet_quality  \
# 0              no                   85.0          8.0         fair
# 1              no                   97.3          4.6         good
# 2              no                   94.8          8.0         poor
# 3              no                   71.0          9.2         poor
# 4              no                   90.9          4.9         fair
# ..            ...                    ...          ...          ...
# 995            no                   77.0          7.5         fair
# 996           yes                   86.0          6.8         poor
# 997            no                   61.9          6.5         good
# 998           yes                  100.0          7.6         fair
# 999            no                   89.4          7.1         good
#
#      exercise_frequency parental_education_level internet_quality  \
# 0                     6                   master          average
# 1                     6              high school          average
# 2                     1              high school             poor
# 3                     4                   master             good
# 4                     3                   master             good
# ..                  ...                      ...              ...
# 995                   2              high school             good
# 996                   1              high school          average
# 997                   5                 bachelor             good
# 998                   0                 bachelor          average
# 999                   2                 bachelor          average
#
#      mental_health_rating extracurricular_participation  exam_score
# 0                       8                           yes        56.2
# 1                       8                            no       100.0
# 2                       1                            no        34.3
# 3                       1                           yes        26.8
# 4                       1                            no        66.4
# ..                    ...                           ...         ...
# 995                     6                           yes        76.1
# 996                     6                           yes        65.9
# 997                     9                           yes        64.4
# 998                     1                            no        69.7
# 999                     8                            no        74.9
#
# [873 rows x 15 columns]

# %%
df["extracurricular_participation"].value_counts()
# Out:
# extracurricular_participation
# no     597
# yes    276
# Name: count, dtype: int64

# %%
#saving cleaned data
df.to_csv('cleaned_data.csv', index=False)
